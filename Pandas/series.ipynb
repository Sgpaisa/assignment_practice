# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1=pd.read_csv('Most Streamed Spotify Songs 2024.csv', encoding='latin-1')

# %%
data2=pd.read_csv('Global YouTube Statistics.csv', encoding='latin-1')

# %%
data2=pd.read_csv('Global YouTube Statistics_twocolumn.csv', encoding='latin-1',index_col='Youtuber').squeeze('columns')

# %%
data2
# Out:
# Youtuber
# T-Series                      245000000
# YouTube Movies                170000000
# MrBeast                       166000000
# Cocomelon - Nursery Rhymes    162000000
# SET India                     159000000
#                                 ...
# Natan por Aï¿                  12300000
# Free Fire India Official       12300000
# Panda                          12300000
# RobTopGames                    12300000
# Make Joke Of                   12300000
# Name: subscribers, Length: 995, dtype: int64

# %%
pd.Series([1,2,3,4,5], index=['milk','bread','butter','eggs','cheese'],name='Grocery List')
# Out:
# milk      1
# bread     2
# butter    3
# eggs      4
# cheese    5
# Name: Grocery List, dtype: int64

# %%
countries = ['USA', 'Canada', 'Germany', 'UK', 'France']
population = [331002651, 37742154, 83783942, 67886011, 65273511]
country_population = pd.Series(population, index=countries, name='Population')
country_population
# Out:
# USA        331002651
# Canada      37742154
# Germany     83783942
# UK          67886011
# France      65273511
# Name: Population, dtype: int64

# %%
batsman=[48, 52, 45, 60, 55]
batsman_series=pd.Series(batsman,dtype='int32')

# %%
batsman_series
# Out:
# 0    48
# 1    52
# 2    45
# 3    60
# 4    55
# dtype: int32

# %%
subjects=['Math','Science','English','History','Art']
marks=[85, 90, 78, 92, 88]
marks_series=pd.Series(marks,index=subjects,name='Marks',dtype='int32')

# %%
marks_series
# Out:
# Math       85
# Science    90
# English    78
# History    92
# Art        88
# Name: Marks, dtype: int32

# %%
value=np.arange(100,115)
print(type(pd.Series(value)))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data_item={'Name': 'Alice', 'Age': 30, 'City': 'New York'}
print(pd.Series(data_item))
# Out:
# Name       Alice
# Age           30
# City    New York
# dtype: object

# %%
values = [10, 20, 30, 40, 50]
series1=pd.Series(values, dtype='int32',name='Numbers',index=['a','b','c','d','e'])

# %%
series1.sort_values()
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# Name: Numbers, dtype: int32

# %%
series1.mode()
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Numbers, dtype: int32

# %%
series1.describe()
# Out:
# count     5.000000
# mean     30.000000
# std      15.811388
# min      10.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      50.000000
# Name: Numbers, dtype: float64

# %%
series1.min()
# Out:
# np.int32(10)

# %%
onecolumn=pd.read_csv('Global YouTube Statistics_onecolumn.csv', encoding='latin-1').squeeze('columns')

# %%
onecolumn.describe()
# Out:
# count          995
# unique         995
# top       T-Series
# freq             1
# Name: Youtuber, dtype: object

# %%
onecolumn
# Out:
# 0                        T-Series
# 1                  YouTube Movies
# 2                         MrBeast
# 3      Cocomelon - Nursery Rhymes
# 4                       SET India
#                   ...
# 990                 Natan por Aï¿
# 991      Free Fire India Official
# 992                         Panda
# 993                   RobTopGames
# 994                  Make Joke Of
# Name: Youtuber, Length: 995, dtype: object

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
dataframe=pd.read_csv('Global YouTube Statistics_twocolumn.csv', encoding='latin-1').squeeze('columns')
dataframe.name = 'youtube dataset'

# %%
dataframe
# Out:
#                        Youtuber  subscribers
# 0                      T-Series    245000000
# 1                YouTube Movies    170000000
# 2                       MrBeast    166000000
# 3    Cocomelon - Nursery Rhymes    162000000
# 4                     SET India    159000000
# ..                          ...          ...
# 990               Natan por Aï¿     12300000
# 991    Free Fire India Official     12300000
# 992                       Panda     12300000
# 993                 RobTopGames     12300000
# 994                Make Joke Of     12300000
#
# [995 rows x 2 columns]

# %%
dataframe.values
# Out:
# array([['T-Series', 245000000],
#        ['YouTube Movies', 170000000],
#        ['MrBeast', 166000000],
#        ...,
#        ['Panda', 12300000],
#        ['RobTopGames', 12300000],
#        ['Make Joke Of', 12300000]], shape=(995, 2), dtype=object)

# %%
dataframe.index
# Out:
# RangeIndex(start=0, stop=995, step=1)

# %%
dataframe.dtypes
# Out:
# Youtuber       object
# subscribers     int64
# dtype: object

# %%
dataframe.astype
# Out:
# <bound method NDFrame.astype of                        Youtuber  subscribers
# 0                      T-Series    245000000
# 1                YouTube Movies    170000000
# 2                       MrBeast    166000000
# 3    Cocomelon - Nursery Rhymes    162000000
# 4                     SET India    159000000
# ..                          ...          ...
# 990               Natan por Aï¿     12300000
# 991    Free Fire India Official     12300000
# 992                       Panda     12300000
# 993                 RobTopGames     12300000
# 994                Make Joke Of     12300000
#
# [995 rows x 2 columns]>

# %%
dataframe.size
# Out:
# 1990

# %%
dataframe.shape
# Out:
# (995, 2)

# %%
dataframe.ndim
# Out:
# 2

# %%
dataframe.name
# Out:
# 'youtube dataset'

# %%
type(onecolumn)
# Out:
# pandas.core.series.Series

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
onecolumn.is_unique
# Out:
# True

# %%
dataframe.head()
# Out:
#                      Youtuber  subscribers
# 0                    T-Series    245000000
# 1              YouTube Movies    170000000
# 2                     MrBeast    166000000
# 3  Cocomelon - Nursery Rhymes    162000000
# 4                   SET India    159000000

# %%
dataframe.tail()
# Out:
#                      Youtuber  subscribers
# 990             Natan por Aï¿     12300000
# 991  Free Fire India Official     12300000
# 992                     Panda     12300000
# 993               RobTopGames     12300000
# 994              Make Joke Of     12300000

# %%
onecolumn.sample()
# Out:
# 293    Kids TV - Nursery Rhymes And Baby Songs
# Name: Youtuber, dtype: object

# %%
dataframe.sample()
# Out:
#         Youtuber  subscribers
# 138  rezendeevil     32100000

# %%
dataframe.value_counts()
# Out:
# Youtuber                                   subscribers
# #Refugio Mental                            14100000       1
# #Refï¿½ï¿½ï¿½ï¿½                           12700000       1
# 123 GO! Spanish                            13800000       1
# 1MILLION Dance Studio                      26100000       1
# 1theK (ï¿½ï¿½ï¿½ï¿½ï                       24500000       1
#                                                          ..
# ýýýýýýýýýýýýýýýý - Al-Remas                17400000       1
# ýýýýýýýýýýýýýýýýýý                         13300000       1
# ýýýýýýýýýýýýýýýýýýýý ýýýýýýýýýýýýýýýýýýýý  14100000       1
# ýýýýýýýýýýýýýýýýýýýýý                      14400000       1
# ýýýýýýýýýýýýýýýýýýýýýý                     18800000       1
# Name: count, Length: 995, dtype: int64

# %%
onecolumn.value_counts()
# Out:
# Youtuber
# T-Series                      1
# YouTube Movies                1
# MrBeast                       1
# Cocomelon - Nursery Rhymes    1
# SET India                     1
#                              ..
# Natan por Aï¿                 1
# Free Fire India Official      1
# Panda                         1
# RobTopGames                   1
# Make Joke Of                  1
# Name: count, Length: 995, dtype: int64

# %%
dataframe
# Out:
#                        Youtuber  subscribers
# 0                      T-Series    245000000
# 1                YouTube Movies    170000000
# 2                       MrBeast    166000000
# 3    Cocomelon - Nursery Rhymes    162000000
# 4                     SET India    159000000
# ..                          ...          ...
# 990               Natan por Aï¿     12300000
# 991    Free Fire India Official     12300000
# 992                       Panda     12300000
# 993                 RobTopGames     12300000
# 994                Make Joke Of     12300000
#
# [995 rows x 2 columns]

# %%
onecolumn.value_counts()
# Out:
# Youtuber
# T-Series                      1
# YouTube Movies                1
# MrBeast                       1
# Cocomelon - Nursery Rhymes    1
# SET India                     1
#                              ..
# Natan por Aï¿                 1
# Free Fire India Official      1
# Panda                         1
# RobTopGames                   1
# Make Joke Of                  1
# Name: count, Length: 995, dtype: int64

# %%
onecolumn.sort_values()
# Out:
# 783                              #Refugio Mental
# 939                             #Refï¿½ï¿½ï¿½ï¿½
# 817                              123 GO! Spanish
# 217                        1MILLION Dance Studio
# 250                         1theK (ï¿½ï¿½ï¿½ï¿½ï
#                          ...
# 517                  ýýýýýýýýýýýýýýýý - Al-Remas
# 866                           ýýýýýýýýýýýýýýýýýý
# 784    ýýýýýýýýýýýýýýýýýýýý ýýýýýýýýýýýýýýýýýýýý
# 752                        ýýýýýýýýýýýýýýýýýýýýý
# 447                       ýýýýýýýýýýýýýýýýýýýýýý
# Name: Youtuber, Length: 995, dtype: object

# %%
dataframe1=dataframe['Youtuber']

# %%
dataframe1.sort_index(ascending=False)
# Out:
# 994                  Make Joke Of
# 993                   RobTopGames
# 992                         Panda
# 991      Free Fire India Official
# 990                 Natan por Aï¿
#                   ...
# 4                       SET India
# 3      Cocomelon - Nursery Rhymes
# 2                         MrBeast
# 1                  YouTube Movies
# 0                        T-Series
# Name: Youtuber, Length: 995, dtype: object

# %%
type(dataframe1)
# Out:
# pandas.core.series.Series

# %%
dataframe1.value_counts()
# Out:
# subscribers
# 12500000    22
# 12400000    20
# 14500000    17
# 15000000    17
# 15100000    16
#             ..
# 64600000     1
# 59300000     1
# 58400000     1
# 58000000     1
# 57600000     1
# Name: count, Length: 289, dtype: int64

# %%
dataframe1.sort_values(ascending=False)
# Out:
# 0      245000000
# 1      170000000
# 2      166000000
# 3      162000000
# 4      159000000
#          ...
# 990     12300000
# 991     12300000
# 992     12300000
# 993     12300000
# 994     12300000
# Name: subscribers, Length: 995, dtype: int64

# %%
#method chaining
dataframe1.sort_values(ascending=False).head(5).values[0]
# Out:
# np.int64(245000000)

# %%
dataframe1copy=dataframe1.copy()

# %%
dataframe1copy
# Out:
# 0      245000000
# 1      170000000
# 2      166000000
# 3      162000000
# 4      159000000
#          ...
# 990     12300000
# 991     12300000
# 992     12300000
# 993     12300000
# 994     12300000
# Name: subscribers, Length: 995, dtype: int64

# %%
dataframe1copy.sort_values(inplace=True)

# %%
dataframe.sort_index()
# Out:
#                        Youtuber  subscribers
# 0                      T-Series    245000000
# 1                YouTube Movies    170000000
# 2                       MrBeast    166000000
# 3    Cocomelon - Nursery Rhymes    162000000
# 4                     SET India    159000000
# ..                          ...          ...
# 990               Natan por Aï¿     12300000
# 991    Free Fire India Official     12300000
# 992                       Panda     12300000
# 993                 RobTopGames     12300000
# 994                Make Joke Of     12300000
#
# [995 rows x 2 columns]

# %%
onecolumn.sort_index()
# Out:
# 0                        T-Series
# 1                  YouTube Movies
# 2                         MrBeast
# 3      Cocomelon - Nursery Rhymes
# 4                       SET India
#                   ...
# 990                 Natan por Aï¿
# 991      Free Fire India Official
# 992                         Panda
# 993                   RobTopGames
# 994                  Make Joke Of
# Name: Youtuber, Length: 995, dtype: object

# %%
len(dataframe)
# Out:
# 995

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(dataframe)
# Out:
# ['T',
#  'Youtuber',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
sorted(dataframe)
# Out:
# ['Youtuber', 'subscribers']

# %%
sorted(dataframe)
# Out:
# ['Youtuber', 'subscribers']

# %%
list(dataframe)
# Out:
# ['Youtuber', 'subscribers']

# %%
type(list(dataframe))
# Out:
# list

# %%
type(dict(dataframe))
# Out:
# dict

# %%
dataframe
# Out:
#                        Youtuber  subscribers
# 0                      T-Series    245000000
# 1                YouTube Movies    170000000
# 2                       MrBeast    166000000
# 3    Cocomelon - Nursery Rhymes    162000000
# 4                     SET India    159000000
# ..                          ...          ...
# 990               Natan por Aï¿     12300000
# 991    Free Fire India Official     12300000
# 992                       Panda     12300000
# 993                 RobTopGames     12300000
# 994                Make Joke Of     12300000
#
# [995 rows x 2 columns]

# %%
'sachin gattani' in dataframe
# Out:
# True

# %%
90 in dataframe.values
# Out:
# False

# %%
for i in dataframe:
    print(i)
# Out:
# Youtuber
# subscribers
# sachin gattani

# %%
for i in dataframe.values:
    print(i)
# Out:
# ['sachin gattani' 245000000 1]
# ['sachin gattani' 170000000 1]
# ['sachin gattani' 166000000 1]
# ['sachin gattani' 162000000 1]
# ['sachin gattani' 159000000 1]
# ['sachin gattani' 119000000 1]
# ['sachin gattani' 112000000 1]
# ['sachin gattani' 111000000 1]
# ['sachin gattani' 106000000 1]
# ['sachin gattani' 98900000 1]
# ['sachin gattani' 96700000 1]
# ['sachin gattani' 96000000 1]
# ['sachin gattani' 93600000 1]
# ['sachin gattani' 89800000 1]
# ['sachin gattani' 86900000 1]
# ['sachin gattani' 83000000 1]
# ['sachin gattani' 80100000 1]
# ['sachin gattani' 75600000 1]
# ['sachin gattani' 75000000 1]
# ['sachin gattani' 71600000 1]
# ['sachin gattani' 71300000 1]
# ['sachin gattani' 70500000 1]
# ['sachin gattani' 68200000 1]
# ['sachin gattani' 66500000 1]
# ['sachin gattani' 65900000 1]
# ['sachin gattani' 65600000 1]
# ['sachin gattani' 64600000 1]
# ['sachin gattani' 61000000 1]
# ['sachin gattani' 59500000 1]
# ['sachin gattani' 59500000 1]
# ...

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
'sachin gattani' in dataframe
# Out:
# False

# %%
sorted(dataframe)
# Out:
# ['Youtuber', 'subscribers']

# %%
for i in dataframe:    
    print(i)
# Out:
# Youtuber
# subscribers

# %%
plot1=dataframe.plot()

# %%
plot2=dataframe.sort_values(ascending=False).head(15).plot(kind='pie')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 plot2=dataframe.sort_values(ascending=False).head(15).plot(kind='pie')
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

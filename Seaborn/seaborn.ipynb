# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
#df = pd.read_parquet("../Matplotlib/df_clean.parquet")
df=pd.read_parquet('D:/visual studio/Module and packages/Matplotlib/df_clean.parquet')
chocsales = pd.read_parquet("D:/visual studio/Module and packages/Matplotlib/chocsales_clean.parquet")

# %%
chocsales.head()
# Out:
#      Sales Person    Country              Product      Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco   January    5320
# 1     Van Tuxwell      India        85% Dark Bars    August    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes      July    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes     April   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  February   13685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
df=pd.read_csv('D:/visual studio/Module and packages/Matplotlib/student_depression_dataset.csv')#data gathering

# %%
chocsales=pd.read_csv('D:/visual studio/Module and packages/Matplotlib/Chocolate Sales.csv')

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
#axis level function-> lineplot()
#style --> style parameter can also add addtional insigh in the graph by changing the plot style
sns.lineplot(data=df,x='Age',y='CGPA',hue='Gender',style='Dietary Habits')
plt.show()

# %%
#figure level funtion-> sns.relplot(,kind='line'), kind='line',kind='scatterplot'
#hue-> it can group or separate teh information in the plot w.r.t a new column
g=sns.relplot(data=df,x='Age',y='CGPA',kind='line',hue='Gender',style='Dietary Habits')
g.savefig('sachin.png')
plt.show()

# %%
chocsales.head()
# Out:
#      Sales Person    Country              Product       Date    Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
tips=sns.load_dataset('tips')

# %%
tips.head(244)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(data=tips,x='day',y='total_bill',hue='sex',style='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.relplot(data=tips,x='day',y='total_bill',hue='smoker',style='sex',kind='line')

# %%
sns.lineplot(data=tips,x='day',y='total_bill',hue='smoker',style='time')
plt.show()

# %%
gap=px.data.gapminder()
#stocks=px.data.stocks()

# %%
#stocks.head()

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
gap.shape
# Out:
# (1704, 8)

# %%
gap['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
gap['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
gap['year'].unique()
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007])

# %%
sns.lineplot(data=gap,x='year',y='lifeExp',hue='continent',size='continent')
plt.grid()
plt.show()

# %%
#gap[(gap['country']=='India') |(gap['country']=='China')|(gap['country']=='Pakistan')]
#isin()--> India,china,pakistan
data=gap[gap['country'].isin(['India','China','Pakistan'])]

# %%
sns.relplot(data=data,x='country',y='lifeExp',kind='line')

# %%
data=gap[gap['country'].isin(['India','Brazil','Germany'])]

# %%
gap[(gap['continent']=='Americas')].value_counts()
# Out:
# country    continent  year  lifeExp  pop       gdpPercap     iso_alpha  iso_num
# Argentina  Americas   1952  62.485   17876956  5911.315053   ARG        32         1
#                       1957  64.399   19610538  6856.856212   ARG        32         1
#                       1962  65.142   21283783  7133.166023   ARG        32         1
#                       1967  65.634   22934225  8052.953021   ARG        32         1
#                       1972  67.065   24779799  9443.038526   ARG        32         1
#                                                                                   ..
# Venezuela  Americas   1987  70.190   17910182  9883.584648   VEN        862        1
#                       1992  71.150   20265563  10733.926310  VEN        862        1
#                       1997  72.146   22374398  10165.495180  VEN        862        1
#                       2002  72.766   24287670  8605.047831   VEN        862        1
# ...

# %%
sns.lineplot(data=data,x='year',y='lifeExp',hue='continent',size='continent')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# ...

# %%
#axes level function
sns.scatterplot(data=df,x='Age',y='CGPA')
plt.show()

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',size='size')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='sex',size='size',kind='scatter')

# %%
sns.relplot(data=gap,x='lifeExp',y='pop',hue='continent')

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips,x='total_bill',y='tip',row='sex',kind='scatter')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',col='sex',kind='scatter')
plt.show()

# %%
sns.relplot(data=tips,x='total_bill',y='tip',col='smoker',kind='scatter',row='sex')
plt.show()

# %%
sns.relplot(data=gap,x='lifeExp',y='pop',col='year',kind='scatter')
plt.show()

# %%
sns.relplot(
    data=gap,
    x='lifeExp',
    y='pop',
    col='year',
    col_wrap=3,
    kind='scatter'
)

plt.show()

# %%
#axis level fn histplot
sns.histplot(data=df,x='Age',bins=120,hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.displot(data=df,x='Age',hue='Gender',kind='hist')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(data=tips,x='total_bill',bins=15,hue='sex',element='poly')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#facetplot w.r.t figure level function
sns.displot(data=tips,x='total_bill',col='sex')

# %%
sns.histplot(data=tips,x='tip',bins=15,hue='sex')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=gap,x='lifeExp')
# Out:
# <Axes: xlabel='lifeExp', ylabel='Count'>

# %%
#kde kernel density estimation plot - > distribution of the data inside a numerical column only
#instead of getting the bin , we can get the smooth curve.probability density function repsenting the distribu of the data with curve
#axis level func sns.kdeplot() data=dataframe,x=column,fill=true or false bydefault
sns.kdeplot(data=df,x='Age',fill=True,hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(data=df,x='Age',hue='Gender',kind='kde',fill=True)
plt.grid()

# %%
sns.kdeplot(data=tips,x='total_bill',fill=True,hue='sex')
plt.grid()
plt.show()

# %%
sns.displot(data=gap,x='lifeExp',kind='kde')
plt.grid()

# %%
#rug plot is not important also small vertical line like ticks along the axis
#more deep the rug plot tick -> more density we can expect ther
#usually used in conjunctin with other plot like kde plot + rug plot
sns.rugplot(data=gap,x='lifeExp')
# Out:
# <Axes: xlabel='lifeExp'>

# %%
sns.kdeplot(data=tips,x='total_bill',hue='sex',fill=True)
sns.rugplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#Bivariate histogram-> creates histogram in both x and y axis as histo with one numerical qty in x direc and one numerical qty in y direction and conjunction of both qtyies creates an rectangel more darker the rectangle -> more density we can have 
sns.histplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
'''bivariate kde plot-> smoothes the x,y observation with 2d gaussian plane
i will create the circular plots 
circular figure closeness (more)-> density more'''
sns.kdeplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
'''matrix plot - relationship between 2-dimension like a table
 
heatmap -> in every classification machine learning problem statement we use the heatmap.heatmap used color shaded to show the size of number in matrix 2-d table
pivot()-> index,column,value-> gap.pivot(index='',columns='',values='')
in matrix plot , we are not having figure level but axis level functn
heatmap()-> data-> annot->cmap--> coolwarm,viridis
 '''
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
dt=gap[(gap['continent']=='Europe')].pivot(index='country',columns='year',values='lifeExp')
plt.figure(figsize=(15,15))
sns.heatmap(data=dt,annot=True,cmap='viridis',linewidth=0.5)
plt.show()

# %%
dt=gap.pivot(index='country',columns='year',values='lifeExp')
sns.heatmap(data=dt)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
#clustermap-> both heatmap and automatic grouping using cluster
#amit= 78,85,93,65
#sunil=48,66,23,12
#raj=79,84,94,67

# it groups the similar rows and similar columns using machine learning algorith internally
#helps in finding hidden pattern in your data

# %%
iris=px.data.iris()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]])

# %%
'''categorical plots
it helps to visualize the relationship where atleast one variable is categorical and other can be categorical/numerical
category - x axis
numerical- y axis
in categorical colum , we group the rows based on the category of categorical column and can apply an aggregation operation on numerica columns.
# barplot - typically shows average value of numerical column
'''
sns.barplot(data=gap,x='continent',y='lifeExp')
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>

# %%
sns.barplot(data=gap,x='continent',y='gdpPercap')
# Out:
# <Axes: xlabel='continent', ylabel='gdpPercap'>

# %%
sns.barplot(data=df,x='Dietary Habits',y='Depression')
# Out:
# <Axes: xlabel='Dietary Habits', ylabel='Depression'>

# %%
sns.barplot(data=tips,x='sex',y='total_bill',hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(data=gap,x='continent')
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
gap[gap['continent']=='Oceania'].value_counts()
# Out:
# country      continent  year  lifeExp  pop       gdpPercap    iso_alpha  iso_num
# Australia    Oceania    1952  69.120   8691212   10039.59564  AUS        36         1
#                         1957  70.330   9712569   10949.64959  AUS        36         1
#                         1962  70.930   10794968  12217.22686  AUS        36         1
#                         1967  71.100   11872264  14526.12465  AUS        36         1
#                         1972  71.930   13177000  16788.62948  AUS        36         1
#                         1977  73.490   14074100  18334.19751  AUS        36         1
#                         1982  74.740   15184200  19477.00928  AUS        36         1
#                         1987  76.320   16257249  21888.88903  AUS        36         1
#                         1992  77.560   17481977  23424.76683  AUS        36         1
#                         1997  78.830   18565243  26997.93657  AUS        36         1
# ...

# %%
sns.countplot(data=tips,x='day')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
# used to get the outlieer and median,quartile
sns.boxplot(data=df,x='CGPA')
# Out:
# <Axes: xlabel='CGPA'>

# %%
sns.boxplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(data=gap,x='continent',y='lifeExp')
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>

# %%
#violin plot-> combination of box plot and kde plot
sns.violinplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.violinplot(data=gap,x='continent',y='lifeExp')
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>

# %%
#swarmplot-> individual data points while avoiding overlapping so density and idividual points
sns.swarmplot(data=chocsales,x='Country',y='Boxes Shipped')
# Out:
# d:\visual studio\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\visual studio\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\visual studio\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\visual studio\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
'''regression plot---relationship between two numerical variables
x and y along with best fit regression line.
regression plot--- combination of scatter plot and line plot
scatter plot-- it can show us the past variation of data
line plot--- it can show us the future tends
example --- study hours vs exam score
regplot()---data---x--numerical column
y--numerical column2
marker--'o'
color-> '''
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(data=gap,x='lifeExp',y='gdpPercap')
# Out:
# <Axes: xlabel='lifeExp', ylabel='gdpPercap'>

# %%
#joinplot-> scatter plot +  histogram
#jointplot()-> x,y,kind
sns.jointplot(data=tips,x='total_bill',y='tip')

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='reg')

# %%
#pairplot - multiple scatter plot and histogram for all comibination of numerical column
sns.pairplot(data=df)

# %%
sns.pairplot(data=tips)

# %%
sns.pairplot(data=chocsales)

# %%
chocsales.head()
# Out:
#      Sales Person    Country              Product       Date    Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
sns.pairplot(data=gap,kind='reg')

# %%
df.head(100)
# Out:
#      id  Gender   Age           City Profession  Academic Pressure  \
# 0     2    Male  33.0  Visakhapatnam    Student                5.0
# 1     8  Female  24.0      Bangalore    Student                2.0
# 2    26    Male  31.0       Srinagar    Student                3.0
# 3    30  Female  28.0       Varanasi    Student                3.0
# 4    32  Female  25.0         Jaipur    Student                4.0
# ..  ...     ...   ...            ...        ...                ...
# 95  525  Female  34.0      Hyderabad    Student                3.0
# 96  529    Male  22.0         Nagpur    Student                4.0
# 97  530    Male  23.0        Lucknow    Student                3.0
# 98  534    Male  24.0         Kalyan    Student                3.0
# 99  535    Male  21.0          Delhi    Student                5.0
#
#     Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0             0.0  8.97                 2.0               0.0
# ...

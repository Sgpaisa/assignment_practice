# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('student_depression_dataset.csv')

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# 3          '7-8 hours'       Moderate      BCA
# 4          '5-6 hours'       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 0                                   Yes               3.0              1.0
# 1                                    No               3.0              2.0
# 2                                    No               9.0              1.0
# 3                                   Yes               4.0              5.0
# 4                                   Yes               1.0              1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0

# %%
df['Age'].value_counts().head(10)
# Out:
# Age
# 24.0    2258
# 20.0    2237
# 28.0    2133
# 29.0    1950
# 33.0    1893
# 25.0    1784
# 21.0    1726
# 23.0    1645
# 18.0    1587
# 19.0    1560
# Name: count, dtype: int64

# %%
data=df.groupby('Age')['CGPA'].mean().head(10)

# %%
data
# Out:
# Age
# 18.0    7.551720
# 19.0    7.662917
# 20.0    7.613572
# 21.0    7.680349
# 22.0    7.526371
# 23.0    7.683191
# 24.0    7.730930
# 25.0    7.765353
# 26.0    7.724130
# 27.0    7.537223
# Name: CGPA, dtype: float64

# %%
x=data.index

# %%
x
# Out:
# Index([18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.0, 26.0, 27.0], dtype='float64', name='Age')

# %%
y=data.values

# %%
y
# Out:
# array([7.55172023, 7.66291667, 7.61357175, 7.68034907, 7.52637069,
#        7.68319149, 7.73093003, 7.76535314, 7.72412987, 7.53722298])

# %%
plt.figure(figsize=(10,6))
plt.title('average CGPA variation as per age')
plt.xlabel('Age')
plt.ylabel('Average CGPA')
plt.scatter(x,y,color='red',marker='^')
plt.grid()
plt.show()

# %%
x=np.linspace(-10,10,50)

# %%
y=10+x+3+np.random.randint(0,300,50)

# %%
plt.figure(figsize=(10,6))
plt.title('random.randint')
plt.xlabel('Age')
plt.ylabel('random.randint')
plt.scatter(x,y,color='red',marker='^')
plt.grid()
plt.show()

# %%
chocsales=pd.read_csv('Chocolate Sales.csv')

# %%
chocsales
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# 3               342
# 4               184
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [1094 rows x 6 columns]

# %%
chocsales.sample(5)
# Out:
#             Sales Person      Country              Product       Date  \
# 751  Rafaelita Blaksland  New Zealand              Eclairs  07-Feb-22
# 992          Brien Boise  New Zealand              Eclairs  11-Jul-22
# 645       Wilone O'Kielt    Australia  Baker's Choco Chips  25-Jan-22
# 56          Ches Bonnell  New Zealand  Spicy Special Slims  14-Feb-22
# 103       Marney O'Breen          USA      99% Dark & Pure  28-Mar-22
#
#        Amount  Boxes Shipped
# 751  $19,481              51
# 992   $4,690             299
# 645   $2,961             154
# 56    $3,556              18
# 103   $4,151             296

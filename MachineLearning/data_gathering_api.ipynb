# %%
#data gathering using API
https://api.themoviedb.org/3/genre/movie/list?api_key=9cdcca2d9061303f4f72db441bdf4e43&language=en
# Out:
#   Cell In[3], line 2
#     https://api.themoviedb.org/3/genre/movie/list?api_key=9cdcca2d9061303f4f72db441bdf4e43&language=en
#                                                           ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# 9cdcca2d9061303f4f72db441bdf4e43
# eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5Y2RjY2EyZDkwNjEzMDNmNGY3MmRiNDQxYmRmNGU0MyIsIm5iZiI6MTc3MjA4MDcxMC4zMjksInN1YiI6IjY5OWZjZTQ2MTFmNTkxNTk2ZGYyMDI0OSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.lxG9tzn205fn1ZqekMNyWJ_gDdOH9b0LfgIz5tqW7LQ

# %%
# import requests()
import requests

# %%
#response=requests.get('https://api.themoviedb.org/3/genre/movie/list?api_key=9cdcca2d9061303f4f72db441bdf4e43&language=en')
#Trending movies list

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5Y2RjY2EyZDkwNjEzMDNmNGY3MmRiNDQxYmRmNGU0MyIsIm5iZiI6MTc3MjA4MDcxMC4zMjksInN1YiI6IjY5OWZjZTQ2MTFmNTkxNTk2ZGYyMDI0OSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.lxG9tzn205fn1ZqekMNyWJ_gDdOH9b0LfgIz5tqW7LQ"}
response2=requests.get('https://api.themoviedb.org/3/trending/movie/day?language=en-US"&api_key=9cdcca2d9061303f4f72db441bdf4e43',headers=headers)
print(response2.status_code)
print(response2.json())
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File d:\visual studio\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# ...

# %% [markdown]
# Data gathering using API
# postive respone is 200 , negative response code 401,10054
# if header is not present then server consider is malicious activity
# hence in vs program-> (url + header)-> like browser authentication ( then it works)
# but again the problem is tmdb also tracks ip address and using ip address they can block the request hence google colab is the wayforward as we are google server

# %%
import requests
import pandas as pd

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5Y2RjY2EyZDkwNjEzMDNmNGY3MmRiNDQxYmRmNGU0MyIsIm5iZiI6MTc3MjA4MDcxMC4zMjksInN1YiI6IjY5OWZjZTQ2MTFmNTkxNTk2ZGYyMDI0OSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.lxG9tzn205fn1ZqekMNyWJ_gDdOH9b0LfgIz5tqW7LQ"}
response2=requests.get('https://api.themoviedb.org/3/trending/movie/day?language=en-US&page=500"&api_key=9cdcca2d9061303f4f72db441bdf4e43',headers=headers)
print(response2.status_code)


df=pd.DataFrame(response2.json()['results'])

df.shape

df.head()

df[['id','title','original_title','overview','adult','popularity','release_date','vote_average','vote_count']]

data=pd.DataFrame()

for i in range(1,501):
  url=f'https://api.themoviedb.org/3/trending/movie/day?language=en-US&page={i}&api_key=9cdcca2d9061303f4f72db441bdf4e43'.format(i)
  headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5Y2RjY2EyZDkwNjEzMDNmNGY3MmRiNDQxYmRmNGU0MyIsIm5iZiI6MTc3MjA4MDcxMC4zMjksInN1YiI6IjY5OWZjZTQ2MTFmNTkxNTk2ZGYyMDI0OSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.lxG9tzn205fn1ZqekMNyWJ_gDdOH9b0LfgIz5tqW7LQ"}
  response2=requests.get(url=url,headers=headers)
  df=pd.DataFrame(response.json()['results'])
  df[['id','title','original_title','overview','adult','popularity','release_date','vote_average','vote_count']]
  data=pd.concat([data,df],ignore_index=False)






data.shape

data.head(100)

data.to_csv('Treding_Movies.csv',index=False)

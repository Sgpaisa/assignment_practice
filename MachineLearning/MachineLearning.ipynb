# %% [markdown]
# ##AI can generate photorealistic images--> Generative adverserial network (GAN)--> deep learning

# %% [markdown]
# Chatgpt-Voice data-text data-> natural language processing-> speech recognition model->trained on huge amount of voice data-> it can perform voice recognition task -> audio data->numerical features->( mel frequency cepstral coefficient( voice data -> on the basis of frequency --> text data by using deep learning model like RNN))

# %% [markdown]
# perform data analysis from data exploration to cleaning to EDA

# %% [markdown]
# chatgpt-> data analysis -> data exploration-> is clean or not , create graph as part of EDA ( exploratory data analysis) -> data preprocessing ( categorical data to numerical)

# %% [markdown]
# data must be preprocesses by using nlp tech-> lowercasing , tokenization,stop word removal,text input into numerical input-> wordtovec, bow -(bag of words),tfidf,ohe (one hard encoding) model-> rnn , lstm ,gru model

# %% [markdown]
# types of supervised learning
# 1. regression- when output is numerial (column) then regression supervised learning
# 2. classification-> when output is categorical (column) then classification based supervised learning

# %% [markdown]
# Un-supervised machine learning-> only input data is their but no output data i.e un-supervised ml ussually dont go with prediction like task----hence grouping and aggregating like task can be carried out ...based on similarities we can grouping the task.
# 1. clustering
# 2. dimenstionality reduction - pca -  principle commonality analysis
# 3. anomaly detction- detecting outlier
# 4. association rule based learning

# %% [markdown]
# semi supervises machin learning
# just few labelling task or data can be labelled and rest of the data will be labelled by algo itself based on similarity in the data points

# %% [markdown]
# Reinforcememnt learing- we let the model to predict on its own and feedback to the model whether the output is correct or not

# %% [markdown]
# midjourney - generate image
# chatgpt  - ghibli images
# sora AI/runway ai - videos

# %% [markdown]
# Tensor is the fundamental unit to store the data structure or container of any model of machine learning , deep learing or any ai to store the numeric data or numirical data
#
# example data-  csv dataset, nlp text data, image data , video data

# %% [markdown]
# Differenet type of tensors
# 1. 0-d tensor- scalar
# 2. 1-d tensor (single row and single column)- cobination of (scalar + vector)
# 3. 2-d - is called as matrix combination of multiple vectors , 3-d-> (text -data )-> NLP -> store in 3-d Tensor only
# 4-d -> image -> image stored in pixel  or colored image stored in channel  in the form of RGB
# 5-d tensors-- matrix of 3-d tensor is 5-d tensor
# example of 5-d tenson- video data - sora ai / runway ai is a model for that

# %% [markdown]
# building Ai model-> bussiness problem -> ml problem=> gathering data-> via csv(kaggle) or API [ open AI , ai application ] or [database sql / nosql ] like user data from meta or facebook via data engineer can gather from data warehouse by ETL(extract tranform load)

# %% [markdown]
# sqlite 3 as python library for extracting data from database.

# %% [markdown]
# web scrapping - gathering the data from web
# library for web scrapping is beautiful soup & requests & pandas

# %% [markdown]
# EDA -> figure out the relationship between input and output column example cgpa,iq and salary is dependedent output column
# also figuring out which column is important to establish the relationship

# %% [markdown]
# after EDA analysis is done -> scikit/sklearn will play an important role as Feature engineering selection

# %% [markdown]
# sklearn -> data encoding generally this means is categorical data to numeric data conversion
# example 1. one hot encoding.
#
# followed feature scaling -> age | salary | the colum is by using sklearn library so that normalization and standardizatino

# %% [markdown]
# train test split with 20% of training purpose data
#
# training
# 1. regression-> linear regression,svr decision tree regression, artifical neural network,decision tree regression , random forest
#
# 2. classfication -> logistic regression,random forest classifier, support vector classifier,knn k nearest neighbou, cnn, naive bias

# %% [markdown]
# Evaluation step -> model prediction is correct or not example mean squarred erro,mean abosolute error , r2 square, rmse (sklearn)

# %% [markdown]
# hyper parameter tuning -> lightning , sound using appropriate parameter selection to train your model using sklear

# %% [markdown]
# ensemble learning example is bagging(parallely for multiple model) or boosting(sequentially like gboost)
# random forest (decision tree)

# %% [markdown]
# deployment->model to file
# pickle api ----json

# %% [markdown]
# testing step->

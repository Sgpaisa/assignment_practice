# %%
import pandas as pd

# %%
df=pd.read_csv('unclean_smartwatch_health_data.csv')

# %%
df.head()
# Out:
#    User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0   4174.0         58.939776               98.809650   5450.390578
# 1      NaN               NaN               98.532195    727.601610
# 2   1860.0        247.803052               97.052954   2826.521994
# 3   2294.0         40.000000               96.894213  13797.338044
# 4   2130.0         61.950165               98.583797  15679.067648
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 1      6.538239375570314  Highly_Active            5
# 2                  ERROR  Highly Active            5
# 3      7.367789630207228          Actve            3
# 4                    NaN  Highly_Active            6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9799 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float64
#  2   Blood Oxygen Level (%)  9700 non-null   float64
#  3   Step Count              9900 non-null   float64
#  4   Sleep Duration (hours)  9850 non-null   object
#  5   Activity Level          9800 non-null   object
#  6   Stress Level            9800 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 547.0+ KB

# %%
df['User ID'].isnull().sum()
# Out:
# np.int64(201)

# %%
df.drop(columns=['User ID'], inplace=True)

# %%
df.head()
# Out:
#    Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0         58.939776               98.809650   5450.390578
# 1               NaN               98.532195    727.601610
# 2        247.803052               97.052954   2826.521994
# 3         40.000000               96.894213  13797.338044
# 4         61.950165               98.583797  15679.067648
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 1      6.538239375570314  Highly_Active            5
# 2                  ERROR  Highly Active            5
# 3      7.367789630207228          Actve            3
# 4                    NaN  Highly_Active            6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        9600 non-null   float64
#  1   Blood Oxygen Level (%)  9700 non-null   float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
#drop missing data
#df.dropna(inplace=True)

# %%
# mean median imputation --> fill the missing data with the mean or median of all  rows of that column  
#while going mean values is always advisable for the outliers .
# median --> most fequent value from the given column, if you allrnge all the values from the low to high side--> in between value 
#mode --> most frequent value is mode.

# %%
df['Heart Rate (BPM)'].describe()
# Out:
# count    9600.000000
# mean       76.035462
# std        19.412483
# min        40.000000
# 25%        64.890152
# 50%        75.220601
# 75%        85.198249
# max       296.593970
# Name: Heart Rate (BPM), dtype: float64

# %%
df['Heart Rate (BPM)'].median()
# Out:
# np.float64(75.22060125775644)

# %%
df['Heart Rate (BPM)'].fillna(df['Heart Rate (BPM)'].median(), inplace=True)

# %%
df['Heart Rate (BPM)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  9700 non-null   float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
df['Heart Rate (BPM)'].value_counts()
# Out:
# Heart Rate (BPM)
# 75.220601     400
# 40.000000      84
# 104.227891      1
# 66.629712       1
# 72.539956       1
#              ...
# 61.367198       1
# 83.545119       1
# 58.797407       1
# 72.505887       1
# 79.062632       1
# Name: count, Length: 9518, dtype: int64

# %%
df['Blood Oxygen Level (%)'].isnull().sum()
# Out:
# np.int64(300)

# %%
#trying to understand the patter and patter mcar - missing completely at random

df[df['Blood Oxygen Level (%)'].isnull()==True]
# Out:
#       Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 10          101.914938                     NaN   2987.568640
# 21           68.310104                     NaN   1058.374274
# 133          77.907578                     NaN  15672.467752
# 134          78.227923                     NaN    789.365922
# 187          89.486636                     NaN   2689.849911
# ...                ...                     ...           ...
# 9834         64.803112                     NaN   1647.308449
# 9861         57.617790                     NaN  14269.737149
# 9885         75.281591                     NaN   3852.160740
# 9905         87.693723                     NaN   2364.028205
# 9979         58.797407                     NaN    359.210435
#
#      Sleep Duration (hours) Activity Level Stress Level
# 10        7.541956463173237      Sedentary            9
# 21        6.456918401449286          Actve            3
# 133       9.079469571860296      Sedentary           10
# ...

# %%
df.describe()
#no outliers in the data set.
# Out:
#        Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count
# count      10000.000000             9700.000000   9900.000000
# mean          76.002867               97.841581   6985.685885
# std           19.020902                1.732863   6885.809680
# min           40.000000               90.791208      0.910138
# 25%           65.322796               96.662683   2021.039657
# 50%           75.220601               98.010642   4962.534599
# 75%           84.791711               99.376179   9724.902880
# max          296.593970              100.000000  62486.690753

# %%
df['Blood Oxygen Level (%)'].fillna(df['Blood Oxygen Level (%)'].mean(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
#forward filling or backward filling-> time series data 
# forward filling -> fill the missing value with the previous value
# backward filling -> fill the missing value with the next value    


df[df['Step Count'].isnull()==True]
# Out:
#       Heart Rate (BPM)  Blood Oxygen Level (%)  Step Count  \
# 136          70.593014               97.473981         NaN
# 204          75.220601               98.710637         NaN
# 603          69.084103               99.627473         NaN
# 716          83.258294               98.704757         NaN
# 739          97.506420               97.651407         NaN
# ...                ...                     ...         ...
# 9097         62.072133               96.810967         NaN
# 9121         54.793814               99.670176         NaN
# 9191        101.777396              100.000000         NaN
# 9527         75.220601               94.694312         NaN
# 9565         90.411615               95.009355         NaN
#
#      Sleep Duration (hours) Activity Level Stress Level
# 136       3.439287691081752  Highly_Active            6
# 204       5.756958709255954  Highly_Active            8
# 603       6.358184719715759  Highly_Active            7
# ...

# %%
# method --> ffill --> forward filling
#backward filling --> bfill
df['Step Count'].fillna(method='ffill', inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_1956\1118214687.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Step Count'].fillna(method='ffill', inplace=True)

# %%
df['Step Count'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              10000 non-null  float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
df[df['Sleep Duration (hours)']=='ERROR']
# Out:
#       Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 2           247.803052               97.052954   2826.521994
# 62          115.078288               99.928041   1918.372142
# 71           64.799778               94.743857   4613.859266
# 81           41.709895               96.857347   1413.015778
# 92           70.243810               97.171134   2336.583406
# ...                ...                     ...           ...
# 9901         63.369107               96.229029   6656.786482
# 9912         75.933666               97.386073   1813.072248
# 9927         87.579045               98.768633   3727.161872
# 9943         91.834863               96.145378  38831.465057
# 9951         70.335328               98.560133   1997.442874
#
#      Sleep Duration (hours) Activity Level Stress Level
# 2                     ERROR  Highly Active            5
# 62                    ERROR  Highly_Active            4
# 71                    ERROR  Highly_Active           10
# ...

# %%
# object data type --> numeric--> pandas--> to_numeric()
df['Sleep Duration (hours)']=pd.to_numeric(df['Sleep Duration (hours)'],errors='coerce')

# %%
df[df['Sleep Duration (hours)']=='ERROR']
# Out:
# Empty DataFrame
# Columns: [Heart Rate (BPM), Blood Oxygen Level (%), Step Count, Sleep Duration (hours), Activity Level, Stress Level]
# Index: []

# %%
df['Sleep Duration (hours)'].value_counts()
# Out:
# Sleep Duration (hours)
# 7.167236    1
# 6.538239    1
# 7.367790    1
# 8.378343    1
# 7.871146    1
#            ..
# 7.402749    1
# 6.382166    1
# 6.916549    1
# 5.691234    1
# 5.691001    1
# Name: count, Length: 9603, dtype: int64

# %%
df['Sleep Duration (hours)'].dtype
# Out:
# dtype('float64')

# %%
df['Sleep Duration (hours)'].mean()
# Out:
# np.float64(6.505462918406444)

# %%
df['Sleep Duration (hours)'].median()
# Out:
# np.float64(6.503308362112644)

# %%
df['Sleep Duration (hours)']=df['Sleep Duration (hours)'].fillna(df['Sleep Duration (hours)'].mean())

# %%
df['Sleep Duration (hours)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              10000 non-null  float64
#  3   Sleep Duration (hours)  10000 non-null  float64
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 468.9+ KB

# %%
#for catogorical column--> mode -> most frequent repeating value in your column 
df['Activity Level'].mode()
# Out:
# 0    Seddentary
# Name: Activity Level, dtype: object

# %%
df['Activity Level'].isnull().sum()
# Out:
# np.int64(200)

# %%
df['Activity Level']=df['Activity Level'].fillna('Seddentary')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              10000 non-null  float64
#  3   Sleep Duration (hours)  10000 non-null  float64
#  4   Activity Level          10000 non-null  object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 468.9+ KB

# %%
# constant imputation-> when you want to fill missing values with a constant value with a constant value like unknown

# %%
df['Stress Level'].value_counts()
# Out:
# Stress Level
# 2            1007
# 7            1006
# 6            1001
# 3             995
# 1             984
# 9             976
# 4             966
# 10            954
# 5             945
# 8             917
# Very High      49
# Name: count, dtype: int64

# %%
df['Stress Level'].fillna(5,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              10000 non-null  float64
#  3   Sleep Duration (hours)  10000 non-null  float64
#  4   Activity Level          10000 non-null  object
#  5   Stress Level            10000 non-null  object
# dtypes: float64(4), object(2)
# memory usage: 468.9+ KB

# %%
#different imputation technique
'''
1. Remove the missing values
2. mean median imputatio -(numeric)
3. mode imputation -> categorical
4. constant or sentinel value imputation
5. forward fill / backward fill ( time series)
6. simple imputation - from scikit learn
'''
# Out:
# '\n1. Remove the missing values\n2. mean median imputatio -(numeric)\n3. mode imputation -> categorical\n4. constant or sentinel value imputation\n5. forward fill / backward fill ( time series)\n6. simple imputation\n'

# %%
df=pd.read_csv('unclean_smartwatch_health_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9799 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float64
#  2   Blood Oxygen Level (%)  9700 non-null   float64
#  3   Step Count              9900 non-null   float64
#  4   Sleep Duration (hours)  9850 non-null   object
#  5   Activity Level          9800 non-null   object
#  6   Stress Level            9800 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 547.0+ KB

# %%
df=df.drop(columns=['User ID'])

# %%
df.head()
# Out:
#    User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0   4174.0         58.939776               98.809650   5450.390578
# 1      NaN               NaN               98.532195    727.601610
# 2   1860.0        247.803052               97.052954   2826.521994
# 3   2294.0         40.000000               96.894213  13797.338044
# 4   2130.0         61.950165               98.583797  15679.067648
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 1      6.538239375570314  Highly_Active            5
# 2                  ERROR  Highly Active            5
# 3      7.367789630207228          Actve            3
# 4                    NaN  Highly_Active            6

# %%
from turtle import st

from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='median')
df['Heart Rate (BPM)']=imputer.fit_transform(df[['Heart Rate (BPM)']]).ravel()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  9700 non-null   float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
df.describe()
# Out:
#        Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count
# count      10000.000000             9700.000000   9900.000000
# mean          76.002867               97.841581   6985.685885
# std           19.020902                1.732863   6885.809680
# min           40.000000               90.791208      0.910138
# 25%           65.322796               96.662683   2021.039657
# 50%           75.220601               98.010642   4962.534599
# 75%           84.791711               99.376179   9724.902880
# max          296.593970              100.000000  62486.690753

# %%
from numpy import ravel


imputer=SimpleImputer(strategy='mean')
df['Blood Oxygen Level (%)']=imputer.fit_transform(df[['Blood Oxygen Level (%)']]).ravel()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
df['Activity Level'].describe()
# Out:
# count           9800
# unique             6
# top       Seddentary
# freq            1676
# Name: Activity Level, dtype: object

# %%
#most frequent is for categorical column
imputer=SimpleImputer(strategy='most_frequent')
df['Activity Level']=imputer.fit_transform(df[['Activity Level']]).ravel()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          10000 non-null  object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
imputer=SimpleImputer(strategy='constant',fill_value=5)
df['Stress Level']=imputer.fit_transform(df[['Stress Level']]).ravel()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          10000 non-null  object
#  5   Stress Level            10000 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
# Convert to numeric first (handles 'ERROR' values), then impute with mean
df['Sleep Duration (hours)'] = pd.to_numeric(df['Sleep Duration (hours)'], errors='coerce')

imputer = SimpleImputer(strategy='mean')
df['Sleep Duration (hours)'] = imputer.fit_transform(df[['Sleep Duration (hours)']]).ravel()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  10000 non-null  float64
#  4   Activity Level          10000 non-null  object
#  5   Stress Level            10000 non-null  object
# dtypes: float64(4), object(2)
# memory usage: 468.9+ KB

# %%
imputer = SimpleImputer(strategy='median')
df['Step Count'] = imputer.fit_transform(df[['Step Count']]).ravel()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              10000 non-null  float64
#  3   Sleep Duration (hours)  10000 non-null  float64
#  4   Activity Level          10000 non-null  object
#  5   Stress Level            10000 non-null  object
# dtypes: float64(4), object(2)
# memory usage: 468.9+ KB

# %%
#data cleaning
import pandas as pd

# %%
df=pd.read_csv('unclean_smartwatch_health_data.csv')

# %%
#data assessment
df.head()
# Out:
#    User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0   4174.0         58.939776               98.809650   5450.390578
# 1      NaN               NaN               98.532195    727.601610
# 2   1860.0        247.803052               97.052954   2826.521994
# 3   2294.0         40.000000               96.894213  13797.338044
# 4   2130.0         61.950165               98.583797  15679.067648
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 1      6.538239375570314  Highly_Active            5
# 2                  ERROR  Highly Active            5
# 3      7.367789630207228          Actve            3
# 4                    NaN  Highly_Active            6

# %%
df.tail()
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)   Step Count  \
# 9995   1524.0         78.819386               98.931927  2948.491953
# 9996   4879.0         48.632659               95.773035  4725.623070
# 9997   2624.0         73.834442               97.945874  2571.492060
# 9998   4907.0               NaN               98.401058  3364.788855
# 9999   4113.0         70.063864               98.475606   544.696104
#
#      Sleep Duration (hours) Activity Level Stress Level
# 9995      7.402748595032027         Active            7
# 9996     6.3821659358529015      Sedentary            2
# 9997       6.91654920303435      Sedentary            4
# 9998      5.691233932149209         Active            8
# 9999      5.691001039740254          Actve            5

# %%
df.sample(5)
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 9686   2935.0         44.955389               97.005527  11917.288413
# 2360   1515.0         61.019726               96.624562   1540.652218
# 6957   3782.0         80.840909               98.766082   1089.520795
# 4605   3343.0         64.264694               99.746421  10772.136083
# 1349   1723.0         57.386581               97.171092   1636.743365
#
#      Sleep Duration (hours) Activity Level Stress Level
# 9686      5.843416496184981         Active            5
# 2360       6.78078102785035            NaN          NaN
# 6957      7.379442371511306         Active            3
# 4605      7.987387625858525  Highly_Active            2
# 1349      7.950007297138251  Highly Active            1

# %%
df.describe()
# Out:
#            User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count
# count  9799.000000       9600.000000             9700.000000   9900.000000
# mean   3007.480253         76.035462               97.841581   6985.685885
# std    1150.581542         19.412483                1.732863   6885.809680
# min    1001.000000         40.000000               90.791208      0.910138
# 25%    1997.500000         64.890152               96.662683   2021.039657
# 50%    2998.000000         75.220601               98.010642   4962.534599
# 75%    4004.000000         85.198249               99.376179   9724.902880
# max    4999.000000        296.593970              100.000000  62486.690753

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9799 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float64
#  2   Blood Oxygen Level (%)  9700 non-null   float64
#  3   Step Count              9900 non-null   float64
#  4   Sleep Duration (hours)  9850 non-null   object
#  5   Activity Level          9800 non-null   object
#  6   Stress Level            9800 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 547.0+ KB

# %%
df.shape
# Out:
# (10000, 7)

# %%
#total no of missing values inside the dataset and every single column
#isnull()-> it will give us the true and false values for the missing values
#sum()-> it will give us the total no of missing values in each column

# %%
df.isnull().sum()
# Out:
# User ID                   201
# Heart Rate (BPM)          400
# Blood Oxygen Level (%)    300
# Step Count                100
# Sleep Duration (hours)    150
# Activity Level            200
# Stress Level              200
# dtype: int64

# %%
#dupliate values
#df.duplicated().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
##drop duplicates
#df.drop_duplicates(inplace=True)

# %%
#dropna() - it will drop all the rows which have missing values
#df.dropna(inplace=True)

# %%
#Data assessment

# what all different results you came up for your data

# remove your id column

# %%
df['Heart Rate (BPM)'].isnull().sum()
# Out:
# np.int64(400)

# %%
df['Heart Rate (BPM)'].value_counts()
# Out:
# Heart Rate (BPM)
# 40.000000     84
# 79.062632      1
# 104.227891     1
# 66.629712      1
# 72.539956      1
#               ..
# 61.367198      1
# 83.545119      1
# 58.797407      1
# 72.505887      1
# 95.372290      1
# Name: count, Length: 9517, dtype: int64

# %%
df['Heart Rate (BPM)'].unique()
# Out:
# array([ 58.93977586,          nan, 247.80305229, ...,  48.63265947,
#         73.83444218,  70.06386353], shape=(9518,))

# %%
df['Heart Rate (BPM)'].max()
# Out:
# np.float64(296.5939695131042)

# %%
df[df['Heart Rate (BPM)']==df['Heart Rate (BPM)'].max()]
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 4185   4643.0         296.59397               95.415588  54698.646371
#
#      Sleep Duration (hours) Activity Level Stress Level
# 4185        8.4611474189254            NaN           10

# %%
df['Heart Rate (BPM)'].plot(kind='box')
# Out:
# <Axes: >

# %%
#dropping missing value as they are less then 5% of the data
df.dropna(subset=['Heart Rate (BPM)'], inplace=True)

# %%
df['Heart Rate (BPM)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['User ID', 'Heart Rate (BPM)', 'Blood Oxygen Level (%)', 'Step Count',
#        'Sleep Duration (hours)', 'Activity Level', 'Stress Level'],
#       dtype='object')

# %%
df=df[['Heart Rate (BPM)', 'Blood Oxygen Level (%)', 'Step Count',
       'Sleep Duration (hours)', 'Activity Level', 'Stress Level']]

# %%
df['Heart Rate (BPM)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Blood Oxygen Level (%)'].isnull().sum()
# Out:
# np.int64(289)

# %%
df['Blood Oxygen Level (%)'].mean()
# Out:
# np.float64(97.84430002023196)

# %%
df['Blood Oxygen Level (%)'].fillna(df['Blood Oxygen Level (%)'].mean(), inplace=True)
#df['Blood Oxygen Level (%)'].fillna(97.8443, inplace=True)

# %%
df['Blood Oxygen Level (%)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Heart Rate (BPM)']=df['Heart Rate (BPM)'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9600 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        9600 non-null   float32
#  1   Blood Oxygen Level (%)  9600 non-null   float64
#  2   Step Count              9506 non-null   float64
#  3   Sleep Duration (hours)  9455 non-null   object
#  4   Activity Level          9409 non-null   object
#  5   Stress Level            9407 non-null   object
# dtypes: float32(1), float64(2), object(3)
# memory usage: 487.5+ KB

# %%
df['Blood Oxygen Level (%)']=df['Blood Oxygen Level (%)'].astype('float32')

# %%
df['Step Count']=df['Step Count'].astype('float32')

# %%
df['Step Count'].isnull().sum()
# Out:
# np.int64(94)

# %%
df['Step Count'].mean()
# Out:
# np.float32(6963.9443)

# %%
#df['Step Count'].fillna(df['Step Count'].mean(),inplace=True)
df.dropna(subset=['Step Count'], inplace=True)

# %%
df['Step Count'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Sleep Duration (hours)'].isnull().sum()
# Out:
# np.int64(144)

# %%
df['Sleep Duration (hours)'].value_counts()
# Out:
# Sleep Duration (hours)
# ERROR                 234
# 5.224139066195455       1
# 5.468413771417153       1
# 7.9544989905339145      1
# 7.541956463173237       1
#                      ...
# 7.331498224681581       1
# 8.830228464836619       1
# 8.035879532058063       1
# 3.691697829588543       1
# 8.378342673824589       1
# Name: count, Length: 9129, dtype: int64

# %%
df['Sleep Duration (hours)']!='Error'
# Out:
# 0       True
# 2       True
# 3       True
# 4       True
# 5       True
#         ...
# 9994    True
# 9995    True
# 9996    True
# 9997    True
# 9999    True
# Name: Sleep Duration (hours), Length: 9506, dtype: bool

# %%
#removal of invalid data-general practice
df=df[df['Sleep Duration (hours)']!='ERROR']

# %%
df['Sleep Duration (hours)'].value_counts()
# Out:
# Sleep Duration (hours)
# 7.167235622316564     1
# 7.367789630207228     1
# 8.378342673824589     1
# 7.871146008904113     1
# 5.224139066195455     1
#                      ..
# 5.428634630125767     1
# 7.402748595032027     1
# 6.3821659358529015    1
# 6.91654920303435      1
# 5.691001039740254     1
# Name: count, Length: 9128, dtype: int64

# %%
df['Sleep Duration (hours)']=df['Sleep Duration (hours)'].astype('float32')

# %%
df['Sleep Duration (hours)'].max()
# Out:
# np.float32(12.140233)

# %%
df['Sleep Duration (hours)'].min()
# Out:
# np.float32(-0.19445279)

# %%
#how to remove outliers
df=df[df['Sleep Duration (hours)']<12.0]
df['Sleep Duration (hours)'].max()
# Out:
# np.float32(11.908386)

# %%
df['Activity Level'].isnull().sum()
# Out:
# np.int64(187)

# %%
df['Activity Level'].value_counts()
# Out:
# Activity Level
# Seddentary       1528
# Sedentary        1525
# Highly Active    1504
# Actve            1490
# Active           1477
# Highly_Active    1416
# Name: count, dtype: int64

# %%
df.dropna(subset=['Activity Level'], inplace=True)

# %%
df['Activity Level'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Stress Level'].dtype
# Out:
# dtype('O')

# %%
df['Stress Level'].value_counts()
# Out:
# Stress Level
# 2            908
# 6            896
# 1            893
# 7            892
# 3            889
# 4            868
# 9            865
# 5            848
# 10           839
# 8            817
# Very High     42
# Name: count, dtype: int64

# %%
df['Stress Level'].isnull().sum()
# Out:
# np.int64(183)

# %%
df['Stress Level'].fillna(5, inplace=True)

# %%
df['Stress Level'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Heart Rate (BPM)          0
# Blood Oxygen Level (%)    0
# Step Count                0
# Sleep Duration (hours)    0
# Activity Level            0
# Stress Level              0
# dtype: int64
